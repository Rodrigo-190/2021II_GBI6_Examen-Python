# %% [markdown]
# <img src="https://www.ikiam.edu.ec/img/logo-ikiam-grey.png" width=300 height=240 />
#
# # EXAMEN PARCIAL PYTHON
#
#
# ## GBI6-2021II: BIOINFORMÁTICA
#
# **Hernández Hurtado, Arnoldd Rodrigo** <--- CAMBIE POR LOS QUE CORRESPONDA A SUS DATOS
#
# **18-02-2021**

# %% [markdown]
# <font color='red'>NO AGREGUE NUEVAS CELDAS, UTILICE ÚNICAMENTE LAS QUE ESTÁN CREADAS</font>

# %% [markdown]
# ### REQUERIMIENTOS PARA EL EXAMEN
# Para este examen se requiere dos documentos:
#
# 1. Archivo ```miningscience.py``` donde tendrá dos funciones:
#
# 2. Archivo ```2021II_GBI6_ExamenParcialPython``` donde se llamará las funciones y se obtendrá resultados.

# %% [markdown]
# ## Ejercicio 1 [2 puntos]
# Cree el archivo ```miningscience.py``` con las siguientes dos funciones:
#
# i. ```download_pubmed```: para descargar la data de PubMed utilizando el **ENTREZ** de Biopython. El parámetro de entrada para la función es el ```keyword```.
#
# ii. ```mining_pubs```: esta función debe utilizar el módulo **re** y utilizar el párametro ```tipo``` para realizar lo siguiente:
#
# * Si el tipo es "DP" recupera el año de publicación del artículo. El retorno es un *dataframe* con el **PMID** y el **DP_year**.
#
# * Si el tipo es "AU" recupera el número de autores por **PMID**. El retorno es un *dataframe* con el **PMID** y el **num_auth**.
#
# * Si el tipo es "AD" recupera el conteo de autores por país. El retorno es un *dataframe* con el **country** y el **num_auth**.
#
# * *Puede utilizar un ```if``` dentro de la función.*
#
# * *Cree un docstring para cada función.*
#
# Luego de crear las funciones, cargue el módulo ```miningscience``` como ```msc``` e imprima docstring de cada función.

# %%
# Escriba aquí su código para el ejercicio 1

# Importanto la libreria
import miningscience as msc

# Imprimiendo el sistema de ayuda integrado (Docstrings) en las funciones del archivo 'miningscience.py' 
help(msc.download_pubmed)
help(msc.mining_pubs)
# Out:
# Help on function download_pubmed in module miningscience:
#
# download_pubmed(keyword)
#     Esta funcion permite la realizacion de una busqueda en la base de datos NCBI
#     'https://pubmed.ncbi.nlm.nih.gov/' con un parametro de entrada keydowrd
#
# Help on function mining_pubs in module miningscience:
#
# mining_pubs(tipo, archivo)
#     La función mining_pubs, utiliza un parametro de ''tipo'', para la busqueda dependiendo de la busqueda realizada en la función ´download_pubmed´
#     - Si es  tipo "DP" -> recuperará el año de publicación del artículo. El retorno será un *dataframe* con el     **PMID** y el **DP_year**.
#     - Si es tipo  "AU" -> recuperará el número de autores por **PMID**. El retorno será un *dataframe* con el **PMID** y el **num_auth**.
#     - Si es tipo "AD" -> recuperará el conteo de autores por país. El retorno será un *dataframe* con el **country** y el **num_auth**.

# %% [markdown]
# ## Ejercicio 2 [1 punto]
#
#
# Utilice la función ```download_pubmed``` para descargar la data con el keyword ```Ecuador genomics``` e imprima lo siguiente:
#
# ```python
# 'El número de artículos es: xx' # xx corresponde al número de artículos recuperados
#
# 'El PMID del primer artículo es: xxxxxxxx' # xxxxxxxx corresponde al ID del artículo en PUDMED
#
# ```

# %%
# Escriba aquí su código para el ejercicio 2

myfile = msc.download_pubmed("Ecuador genomics")
import re
mysubfile = re.findall(r"PMID- ", myfile)
print("El número de articulos en la data Ecuador genomics es: ", len(mysubfile))
mysubfile2 = re.findall(r"\d{8}", myfile)
print("El PMID del primer articulo la data Ecuador genomics es: ", mysubfile2[0])
# Out:
# El número de articulos en la data Ecuador genomics es:  193
# El PMID del primer articulo la data Ecuador genomics es:  35121084

# %% [markdown]
# ## Ejercicio 3 [1 punto]
#
# Utilice la función ```mining_pubs``` para crear los siguientes dataframes:
#
# * pub_year
#
# * pub_authors
#
# * coutries
#
# Muestre los dos primeros y los dos últimos registros de cada dataframe.

# %%
# Escriba aquí su código para el ejercicio 3

# Guardando e imprimiendo, los 2 primeros y ultimos registros de la data de los años de publicacion en datafranes
pub_year = msc.mining_pubs("DP","data/Ecuador_genomics")
print(pub_year.head(2))
print(pub_year.tail(2)) 

# Guardando e imprimiendo, los 2 primeros y ultimos registros de la data de los autores en datafranes
pub_authors = msc.mining_pubs("AU","data/Ecuador_genomics")
print(pub_authors.head(2))
print(pub_authors.tail(2)) 

# Guardando e imprimiendo, los 2 primeros y ultimos registros de la data de paises en datafranes
countries = msc.mining_pubs("AD","data/Ecuador_genomics")
print(countries.head(2))
print(countries.tail(2))
# Out:
#        PMID Año de publicación
# 0                         2022
# 1  35121084               2022
#          PMID Año de publicación
# 191  19018989               2007
# 192  17187350               1996
#        PMID  Numero de autores
# 0  35121084                 12
# 1  35120121                 14
#          PMID  Numero de autores
# 191  17187350                  1
# 192   8661097                  9
#         pais  numero de autores
# 0  Argentina                 44
# 1     Canada                 83
#            pais  numero de autores
# 67  Netherlands                  3
# 68      MexicoF                  4

# %% [markdown]
# ## Ejercicio 4 [2 puntos]
#
# Realice la visualización de los datos del ejercicio 3.
#
# * ```pubyear```: utilizando el conteo artículos por año, calcule la media y la desviación estandar (asumiendo que la distribución es normal). Realice un gráfico de la distribución normal de sus datos. Coloque el título, leyenda de los ejes "x" e "y", y la leyenda de la curva (utilice las expresiones matemáticas tipos latex de ser necesario).
#
# * ```pub_authors```: realice un boxplot del conteo de autores por artículo. Coloque las leyendas adecuadas para cada eje y el título.
#
# * ```countries```: realice una nube de puntos (adaptación de su tarea), resalte al menos 3 países con flechas. Coloque las leyendas adecuadas para cada eje y el título.

# %%
# Escriba aquí su código para el literal 'a' correspondiente al ejercicio 4

import pandas as pd
import numpy as np
import scipy.stats as sts
import matplotlib.pyplot as plt
import csv as csv

print ('Distribución normal')
i = pub_year.iloc[:,1]
s = pd.Series(i)
h = list(set(s))
g=s
f=h
h=[0]*len(f)
k=0
for elem in f:
    d=0
    for comp in g:
        if elem == str(comp):
            d=d+1
    h[k]=d
    k=k+1
print ('Articulos por año :',h)
mean = np.average(h)
print ('El promedio es: ',mean)
stan = np.std(h)
print ('La desviación estándar es: ',stan)
x = np.linspace(mean - 3*stan, mean + 3*stan, 100)
sigma = stan
label = '$\mu = %.1f, \ \sigma^2=%.1f$' %(mean, stan)
y_norm = sts.norm.pdf(x, mean, sigma)
plt.plot(x, y_norm, label=label, c = 'lightseagreen')
plt.xlabel('Número de publicaciones')
plt.ylabel('Prob en el número de publicaciones')
plt.title('Distribución Normal')
plt.legend(title = "Parámetros")
plt.savefig("Distribución normal de la data.jpg")
plt.show()
# Out:
# Distribución normal
# Articulos por año : [36, 15, 23, 14, 6, 1, 1, 1, 1, 1, 21, 2, 1, 8, 22, 40]
# El promedio es:  12.0625
# La desviación estándar es:  12.631650476085854

# %%
# Escriba aquí su código para el literal 'b' correspondiente al ejercicio 4
i = pub_authors.iloc[:,1]
s = pd.Series(i)
s1 = s.tolist()
#s1.pop(79) #Eliminamos el dato atípico
fig = plt.figure(1, figsize=(9, 6))
ax = fig.add_subplot(111)
bp = ax.boxplot(s1)
plt.xlabel('N° de autores por articulo')
plt.ylabel('N° total de Autores')
plt.title('Boxplot conteo de autores por articulo')
plt.savefig("Boxplot conteo de autores por articulo.jpg")
plt.show()
# Out:
#  BOXPLOT

# %%
# Escriba aquí su código para el literal 'c' correspondiente al ejercicio 4
import re
import itertools
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

f = open('data/Ecuador genomics.txt',errors = 'ignore')
files = f.read()
File = re.sub(r"\n\s{6}", " " , files)

My_files = re.findall(r"\,\s[A-Z]+[A-z]{2,11}\.", File)
unique_codes = list(set(My_files))
unique_codes.sort()

a = "".join(unique_codes)
b = a.split(", ")
c = "".join(b)
unique_zipcodes = c.split(".")

#####cambiar Paises_ubicacion.csv #### por Coordenadas.csv
Coordenadas = pd.read_csv('data/data_Coordenadas.csv', engine='python', skipfooter=3)
Coordenadas.columns = ["ID_País", "Latitud", "Longitud", "Nombre"]

datos_nombre = Coordenadas[Coordenadas.Nombre.isin(unique_zipcodes)]
datos_paises = Coordenadas[Coordenadas.ID_País.isin(unique_zipcodes)]
all_data =pd.concat([datos_nombre,datos_paises]).drop_duplicates().sort_values('Nombre')

plt.scatter(all_data.Longitud, all_data.Latitud, s=100, c=all_data.Latitud)
plt.colorbar()
ard = dict(arrowstyle="->")
plt.annotate('AUSTRALIA', xy = (133.775136, -25.274398), 
               xytext = (133.775136, -20), arrowprops= ard)
plt.annotate('BRASIL', xy = (-51.92528, -14.235004), 
               xytext = (-51.92528, -9.5), arrowprops= ard)
plt.annotate('BELGICA', xy = (4.469936, 50.503887), 
               xytext = (9.469936, 38), arrowprops = ard)
plt.annotate('CHINA', xy = (104.195397, 35.86166), 
               xytext = (104.195397, 39), arrowprops= ard)
plt.annotate('NORUEGA', xy = (8.468946, 60.472024), 
               xytext = (8.468946, 63), arrowprops= ard)
plt.annotate('ARGENTINA', xy = (-63.616672,	-38.416097), 
               xytext = (-63.616672, -36), arrowprops= ard)
plt.annotate('BOLIVIA', xy = (-63.588653,	-16.290154), 
               xytext = (-63.588653, -6), arrowprops= ard)
params = plt.gcf()
plSize = params.get_size_inches()
params.set_size_inches( (plSize[0] * 3, plSize[1] * 3) )
plt.title("Nube de puntos de publicaciones")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.savefig("Mapa de paises.jpg")

# %% [markdown]
# ## Ejercicio 5 [1 punto]
#
# Interprete los resultados del **ejercicio 4**

# %% [markdown]
# ### Escriba la respuesta del ejercicio 5
#
# * ```pubyear```: La grafica de distribución normal, muestra una media de 12.1, lo cual sugiere que hay una baja probabilidad de publicaciones.
#
# * ```pub_authors```:  Se logra notar una tendencia creciente de numero de publicaciones por autor, en donde cada autor tiene almenos 8 publicaciones.
#
# * ```countries```: La distribución espacial de autores por país, muestra una incidencia de un mayor número de autores que tienen publicaciones en Ecuador.

# %% [markdown]
# ## Ejercicio 6 [2 puntos]
#
# Para algún gen de interés, realice lo siguiente:
#
# 1. Una búsqueda en la página del [NCBI nucleotide](https://www.ncbi.nlm.nih.gov/nucleotide/).
#
# 2. Descargue el ```Accession List``` de su búsqueda.
#
# 3. Cargue el ```Accession List``` en este notebook y haga una descarga de la data tipo ```genbank``` utilizando los diez primeros IDs de accesión.
#
# 4. Arme un árbol filogenético para los resultados del paso 3.
#
# 5. Interprete el árbol del paso 4.

# %%
# Escriba aquí su código para el ejercicio 6
import Bio as Bio
from Bio import AlignIO
from Bio import Phylo
import matplotlib
import matplotlib.pyplot as plt

# read the file 

import csv
from Bio import SeqIO
from Bio import Entrez

fasta_file = {}
ct = 0

Entrez.email = "arnoldd.hernandez@est.ikiam.edu.ec"
with open('data/sequence (4).seq') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        print(row)
        with Entrez.efetch(db="nucleotide", rettype="gb", retmode = "text", id = row[0]) as handle:
            for seq_record in SeqIO.parse(handle, "gb"):
                fasta_file[row[0]] = str(seq_record.seq)
                ct += 1  
      
print("Number of sequences in file:", ct)

# save all sequences in the multi-fasta file "sequences_general.txt"

f = open("sequencesfiles.txt","w+")
for keys,values in fasta_file.items():
    f.write(">" + str(keys) + "\n" + str(values) + "\n")
f.close()

from Bio.Align.Applications import ClustalOmegaCommandline

in_file = "sequencesfiles.txt"

out_file = "SecuencesAlignment.aln"

clustalomega_cline = ClustalOmegaCommandline(infile = in_file, outfile = out_file, verbose=True, auto=False)

print(clustalomega_cline)

# WINDOWS
# Python will fill out clustal omega in the command line for you!
path = "r'" + str(wdir) #.'
input_command = '"' + wdir + '/clustal-omega-1.2.2-win64/' + str(clustalomega_cline)[0:8] + '" ' + str(clustalomega_cline)[9:] + '-threads=1'
os.system(input_command)

with open("data/SequenceAlignment.aln","r") as aln: 
    alignment = AlignIO.read(aln,"clustal")
#print(type(alignment))
from Bio.Phylo.TreeConstruction import DistanceCalculator 
calculator = DistanceCalculator('identity')
distance_matrix = calculator.get_distance(alignment)
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
constructor = DistanceTreeConstructor(calculator)
shark_tree = constructor.build_tree(alignment)
shark_tree.rooted = True
#print(shark_tree)
Phylo.write(shark_tree, "shark_tree.xml", "phyloxml")
Phylo.draw_ascii(shark_tree)

fig = plt.figure(figsize=(13, 5), dpi=100) 
matplotlib.rc('font', size=12)             
matplotlib.rc('xtick', labelsize=10)       
matplotlib.rc('ytick', labelsize=10)      
axes = fig.add_subplot(1, 1, 1)
plt.savefig("phylogenetic tree.jpg")
Phylo.draw(shark_tree, axes=axes)
# Out:
#  , JF727166.2Pan
#  |
#  | JF727179.2Pan
#  |
# _| JF727176.2Pan
#  |
#  | ____________________________________________________________ EU095335.1Pan
#  ,|
#  || NC_001643.1Pan
#  |
#  | JF727173.1Pan

# %% [markdown]
# **Escriba aquí la interpretación del árbol**

# %% [markdown]
# El chimpancé central, *Pan troglodytes troglodytes*, es un
# subespecie del chimpancé común, originario principalmente en Gabón, Camerún y la República del Congo, pero también, en menor medida, en otras regiones. Hasta la fecha, los cuatro. Las subespecies se reconocen comúnmente en la especie Pan troglodytes:*the West African Chimpanzee P. t. verus*, the *NigeriaCameroon Chimpanzee P. t. ellioti*, the *Central Chimpanzee P. t. troglodytes*, and the *Eastern Chimpanzee P. t. schweinfurthii*. To date, however, only the mitochondrial genome sequences of P. t. vellerosus (GU112742) and P. t. ellioti (KM679417) have been reported.  Sin embargo, hasta la fecha, solo las secuencias del genoma mitocondrial de P. t. vellerosus (GU112742) y P. t. ellioti (KM679417) han sido reportados.
#
# En el arbol filogenetico se puede observar que en las 6 cepas. JF727166.2Pan, JF727179.2Pan, JF727176.2Pan son semejantes entre si, coincidiendo en Inner3, mientras que a su vez se separa de JF727173.1Pan en Inner 2, y a la vez hay otra separación en Inner en donde se encuentran las cepas NC_001643.1Pan y EU095335.1Pan.
#
#
# - Liu B, Hu XD, Gao LZ. The complete mitochondrial genome of the central chimpanzee, Pan troglodytes troglodytes. Mitochondrial DNA A DNA Mapp Seq Anal. 2016 Jul;27(4):2775-6. doi: 10.3109/19401736.2015.1053060. Epub 2015 Jul 20. PMID: 26190079.

# %% [markdown]
# ## Ejercicio 7 [1 punto]
#
#
# 1. Cree en GitHub un repositorio de nombre ```GBI6_ExamenPython```.
# 2. Cree un archivo ```Readme.md``` que debe tener lo siguiente:
# - Datos personales
# - Características del computador
# - Versión de Python/Anaconda y de cada uno de los módulos/paquetes y utilizados
# - Explicación de la data utilizada
#
# 3. Cree un directorio de nombre ```data``` donde deben estar guardado la data utilizada
# 4. Realice al menos 1 control de la versión (commits) por cada ejercicio (del 1 al 6), con un mensaje que inicie como:
#
# ```sh
# Carlitos Alimaña ha realizado .....
# ```
